# %% [markdown]
# # exploring the datasets

# %%
# importing libraries
import pandas as pd

# %%
# importing datasets
campaigns = pd.read_csv("../data/campaigns_inventory_updated.csv", low_memory=False)
briefing = pd.read_csv("../data/briefing.csv")
global_design = pd.read_json("../data/global_design_data.json")

# %%
# visualizing tables
print(campaigns.shape)
campaigns.head()
# Out:
# (422387, 13)
#          type width height campaign_id creative_id  \
# 0  impression     %      %     l5kk3r3    x83byc8a
# 1  impression     %      %     l5kk3r3    x83byc8a
# 2  impression     %      %     l5kk3r3    tf2htrrm
# 3  impression     %      %     l5kk3r3    x83byc8a
# 4  impression     %      %     l5kk3r3    x83byc8a
#
#                              auction_id                browser_ts  \
# 0  fd74243f-6606-4830-a0ef-dd12f66ec6f5  2021-01-01T19:55:20.291Z
# 1  fd74243f-6606-4830-a0ef-dd12f66ec6f5  2021-01-01T19:55:20.298Z
# 2  b3af878b-fd1a-4c6f-91a2-4e3670d2fda5  2021-01-05T00:21:39.693Z
# 3  b7c22590-e784-43cf-874d-a661ad99601f  2021-01-06T09:30:44.188Z
# 4  b7c22590-e784-43cf-874d-a661ad99601f  2021-01-06T09:30:45.047Z
#
#                                             game_key geo_country  \
# 0  adunit-facebook-conversational-commerce-phase-...    Thailand
# 1  adunit-facebook-conversational-commerce-phase-...    Thailand
# 2  adunit-facebook-conversational-commerce-phase-...    Thailand
# 3  adunit-facebook-conversational-commerce-phase-...    Thailand
# 4  adunit-facebook-conversational-commerce-phase-...    Thailand
#
#             site_name platform_os device_type                     browser
# 0  www.wuxiaworld.com           6      Mobile                      Chrome
# 1  www.wuxiaworld.com           6      Mobile  Mobile Safari UI/WKWebView
# 2  www.prachachat.net           6      Mobile               Chrome Mobile
# 3  www.prachachat.net           6      Mobile               Mobile Safari
# 4  www.prachachat.net           6      Mobile                      Chrome

# %%
# checking columns

campaigns.columns
# Out:
# Index(['type', 'width', 'height', 'campaign_id', 'creative_id', 'auction_id',
#        'browser_ts', 'game_key', 'geo_country', 'site_name', 'platform_os',
#        'device_type', 'browser'],
#       dtype='object')

# %%
# checking briefing

print(briefing.shape)
briefing.head()
# Out:
# (101, 21)
#   campaign_id                                      campaign_name  \
# 0     shg01yl  Lexus East | Boston | Sensory Video |  CPM - C...
# 1     rom3zao         Lexus East | Boston | Sensory Video |  CPM
# 2     lvkar9i         Lexus East | Boston | Sensory Video |  CPE
# 3     8muucqy      Lexus East | Boston | Sensory Video |  CPE AV
# 4     xygdmea  Lexus East | Boston | Sensory Video |  CPE - C...
#
#     Submission Date                                        Description  \
# 0  14/02/2020 14:48  Hey Kentaro - Below is the info for the Lexus ...
# 1  14/02/2020 14:48  Hey Kentaro - Below is the info for the Lexus ...
# 2  14/02/2020 14:48  Hey Kentaro - Below is the info for the Lexus ...
# 3  14/02/2020 14:48  Hey Kentaro - Below is the info for the Lexus ...
# 4  14/02/2020 14:48  Hey Kentaro - Below is the info for the Lexus ...
#
#   Campaign Objectives                  KPIs  \
# 0     Brand Awareness  CTR\nEngagement Rate
# 1     Brand Awareness  CTR\nEngagement Rate
# 2     Brand Awareness  CTR\nEngagement Rate
# 3     Brand Awareness  CTR\nEngagement Rate
# 4     Brand Awareness  CTR\nEngagement Rate
#
#                                  Placement(s)   StartDate     EndDate  \
# 0  320x480 (Fullscreen mobile / interstitial)  01/03/2020  30/11/2020
# 1  320x480 (Fullscreen mobile / interstitial)  01/03/2020  30/11/2020
# 2  320x480 (Fullscreen mobile / interstitial)  01/03/2020  30/11/2020
# 3  320x480 (Fullscreen mobile / interstitial)  01/03/2020  30/11/2020
# 4  320x480 (Fullscreen mobile / interstitial)  01/03/2020  30/11/2020
#
#         Serving Location(s)  ...  \
# 0  NY, Boston, Philadelphia  ...
# 1  NY, Boston, Philadelphia  ...
# 2  NY, Boston, Philadelphia  ...
# 3  NY, Boston, Philadelphia  ...
# 4  NY, Boston, Philadelphia  ...
#
#   Delivery Requirements (Black/Audience/White List) Cost Centre Currency  \
# 0                                               NaN         USA      USD
# 1                                               NaN         USA      USD
# 2                                               NaN         USA      USD
# 3                                               NaN         USA      USD
# 4                                               NaN         USA      USD
#
#   Buy Rate (CPE)  Volume Agreed  Gross Cost/Budget  Agency Fee Percentage  \
# 0            0.4       531179.0           212471.6  Percentage        0.0
# 1            0.4       531179.0           212471.6  Percentage        0.0
# 2            0.4       531179.0           212471.6  Percentage        0.0
# 3            0.4       531179.0           212471.6  Percentage        0.0
# 4            0.4       531179.0           212471.6  Percentage        0.0
#
#    Flat Fee  Net Cost
# 0       NaN  212471.6
# 1       NaN  212471.6
# 2       NaN  212471.6
# 3       NaN  212471.6
# 4       NaN  212471.6
#
# [5 rows x 21 columns]

# %%
# checking columns

briefing.columns
# Out:
# Index(['campaign_id', 'campaign_name', 'Submission Date', 'Description',
#        'Campaign Objectives', 'KPIs', 'Placement(s)', 'StartDate', 'EndDate',
#        'Serving Location(s)', 'Black/white/audience list included?',
#        'Delivery Requirements (Black/Audience/White List)', 'Cost Centre',
#        'Currency', 'Buy Rate (CPE)', 'Volume Agreed', 'Gross Cost/Budget',
#        'Agency Fee', 'Percentage', 'Flat Fee', 'Net Cost'],
#       dtype='object')

# %%
print(global_design.shape)
global_design.head()
# Out:
# (1001, 838)
#                                        f910338e60315f02812b05e932068f47  \
# 1028d033d74dd2e24f67  {'labels': {'engagement': ['Asphalt', 'Tarmac'...
# 9e1c545a4b490a7c3088                                                NaN
# e7370ccd417a54394cfc                                                NaN
# a034c30acd4658d468a4                                                NaN
# 8fd373d2d72b97b68c49                                                NaN
#
#                                        444e104ea378baae87997c41eec5b2ff  \
# 1028d033d74dd2e24f67                                                NaN
# 9e1c545a4b490a7c3088  {'labels': {'engagement': [], 'click_through':...
# e7370ccd417a54394cfc  {'labels': {'engagement': [], 'click_through':...
# a034c30acd4658d468a4                                                NaN
# 8fd373d2d72b97b68c49                                                NaN
#
#                                        988c2b4ece7a909bccc88bc7d3168348  \
# 1028d033d74dd2e24f67                                                NaN
# 9e1c545a4b490a7c3088                                                NaN
# e7370ccd417a54394cfc                                                NaN
# a034c30acd4658d468a4  {'labels': {'engagement': ['Person', 'Human', ...
# 8fd373d2d72b97b68c49  {'labels': {'engagement': ['Human', 'Person', ...
#
#                      06653b2a4fa8d2652bb7bca2100aefca  \
# 1028d033d74dd2e24f67                              NaN
# 9e1c545a4b490a7c3088                              NaN
# e7370ccd417a54394cfc                              NaN
# a034c30acd4658d468a4                              NaN
# 8fd373d2d72b97b68c49                              NaN
#
#                      ffaa0f351ee62e98a7d0e8f5fd6f78f1  \
# 1028d033d74dd2e24f67                              NaN
# 9e1c545a4b490a7c3088                              NaN
# e7370ccd417a54394cfc                              NaN
# a034c30acd4658d468a4                              NaN
# 8fd373d2d72b97b68c49                              NaN
#
#                      d7c5bf54f39eb745b553d06813cffb23 adunit-audi-a4-tw-mpu  \
# 1028d033d74dd2e24f67                              NaN                   NaN
# 9e1c545a4b490a7c3088                              NaN                   NaN
# e7370ccd417a54394cfc                              NaN                   NaN
# a034c30acd4658d468a4                              NaN                   NaN
# 8fd373d2d72b97b68c49                              NaN                   NaN
#
#                      adunit-honda-san-diego-mob  \
# 1028d033d74dd2e24f67                        NaN
# 9e1c545a4b490a7c3088                        NaN
# e7370ccd417a54394cfc                        NaN
# a034c30acd4658d468a4                        NaN
# 8fd373d2d72b97b68c49                        NaN
#
#                      4a61c1f8a9beef553affa97c25e1c2d6  \
# 1028d033d74dd2e24f67                              NaN
# 9e1c545a4b490a7c3088                              NaN
# e7370ccd417a54394cfc                              NaN
# a034c30acd4658d468a4                              NaN
# 8fd373d2d72b97b68c49                              NaN
#
#                      adunit-estee-lauder-double-wear-19-fr  ...  \
# 1028d033d74dd2e24f67                                   NaN  ...
# 9e1c545a4b490a7c3088                                   NaN  ...
# e7370ccd417a54394cfc                                   NaN  ...
# a034c30acd4658d468a4                                   NaN  ...
# 8fd373d2d72b97b68c49                                   NaN  ...
#
#                      8a18443441d6bf43be030742905f20ef  \
# 1028d033d74dd2e24f67                              NaN
# 9e1c545a4b490a7c3088                              NaN
# e7370ccd417a54394cfc                              NaN
# a034c30acd4658d468a4                              NaN
# 8fd373d2d72b97b68c49                              NaN
#
#                      ed7238ab853e1fbdc7082ca00e9ef473  \
# 1028d033d74dd2e24f67                              NaN
# 9e1c545a4b490a7c3088                              NaN
# e7370ccd417a54394cfc                              NaN
# a034c30acd4658d468a4                              NaN
# 8fd373d2d72b97b68c49                              NaN
#
#                      d142da38c2a0ee48c4e7634050a2ee86  \
# 1028d033d74dd2e24f67                              NaN
# 9e1c545a4b490a7c3088                              NaN
# e7370ccd417a54394cfc                              NaN
# a034c30acd4658d468a4                              NaN
# 8fd373d2d72b97b68c49                              NaN
#
#                      140322a887f50a9fb74141771658e1ae  \
# 1028d033d74dd2e24f67                              NaN
# 9e1c545a4b490a7c3088                              NaN
# e7370ccd417a54394cfc                              NaN
# a034c30acd4658d468a4                              NaN
# 8fd373d2d72b97b68c49                              NaN
#
#                      adunit-hersheys-cvs-userchoice-mob  \
# 1028d033d74dd2e24f67                                NaN
# 9e1c545a4b490a7c3088                                NaN
# e7370ccd417a54394cfc                                NaN
# a034c30acd4658d468a4                                NaN
# 8fd373d2d72b97b68c49                                NaN
#
#                      adunit-the-angry-birds-2-mpu  \
# 1028d033d74dd2e24f67                          NaN
# 9e1c545a4b490a7c3088                          NaN
# e7370ccd417a54394cfc                          NaN
# a034c30acd4658d468a4                          NaN
# 8fd373d2d72b97b68c49                          NaN
#
#                      adunit-clinica-forticus-brazil-mob  \
# 1028d033d74dd2e24f67                                NaN
# 9e1c545a4b490a7c3088                                NaN
# e7370ccd417a54394cfc                                NaN
# a034c30acd4658d468a4                                NaN
# 8fd373d2d72b97b68c49                                NaN
#
#                      25a1fa274cb8a457064b0c829cf4731f  \
# 1028d033d74dd2e24f67                              NaN
# 9e1c545a4b490a7c3088                              NaN
# e7370ccd417a54394cfc                              NaN
# a034c30acd4658d468a4                              NaN
# 8fd373d2d72b97b68c49                              NaN
#
#                      03030ef7ac15448057777032d26d5474  \
# 1028d033d74dd2e24f67                              NaN
# 9e1c545a4b490a7c3088                              NaN
# e7370ccd417a54394cfc                              NaN
# a034c30acd4658d468a4                              NaN
# 8fd373d2d72b97b68c49                              NaN
#
#                      4fadbbfc2d8dfe3c480064bede98600d
# 1028d033d74dd2e24f67                              NaN
# 9e1c545a4b490a7c3088                              NaN
# e7370ccd417a54394cfc                              NaN
# a034c30acd4658d468a4                              NaN
# 8fd373d2d72b97b68c49                              NaN
#
# [5 rows x 838 columns]

# %%
import json
import pprint
import pandas as pd
from flatten_json import flatten

with open('../data/global_design_data.json') as json_file:
  nested_json = json.load(json_file)

out = {}
def flatten(x, name=''):
    if type(x) is dict:
        for a in x:
            flatten(x[a], name + a + '&')
    else:
        out[name[:-1]] = x
    return out

df = pd.Series(flatten(nested_json)).to_frame()

# %%
df.head(50)
# Out:
#                                                                                                     0
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                    [Asphalt, Tarmac, Road, Runway]
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                    [Asphalt, Tarmac, Road, Runway]
# f910338e60315f02812b05e932068f47&1028d033d74dd2...  [Amazing Hong Kong, air, deals!, Swipe Up, BES...
# f910338e60315f02812b05e932068f47&1028d033d74dd2...  [Amazing Hong Kong, air, deals!, Swipe Up, BES...
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                153
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                154
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                167
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.219551
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.073684
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.627451
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 32
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 43
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 66
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.148237
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.346939
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.192157
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 11
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 25
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 36
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.132212
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.531915
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.092157
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 72
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                104
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                157
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.109776
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.371179
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                            0.44902
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 49
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 74
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                123
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.104167
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.430233
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.337255
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                107
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                129
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                165
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.100962
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.243697
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.533333
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 67
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 73
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 82
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.098558
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.100671
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.292157
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 90
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 28
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                                 45
# f910338e60315f02812b05e932068f47&1028d033d74dd2...                                           0.043269

# %%
df2 = df.reset_index()
df2.head()
# Out:
#                                                index  \
# 0  f910338e60315f02812b05e932068f47&1028d033d74dd...
# 1  f910338e60315f02812b05e932068f47&1028d033d74dd...
# 2  f910338e60315f02812b05e932068f47&1028d033d74dd...
# 3  f910338e60315f02812b05e932068f47&1028d033d74dd...
# 4  f910338e60315f02812b05e932068f47&1028d033d74dd...
#
#                                                    0
# 0                    [Asphalt, Tarmac, Road, Runway]
# 1                    [Asphalt, Tarmac, Road, Runway]
# 2  [Amazing Hong Kong, air, deals!, Swipe Up, BES...
# 3  [Amazing Hong Kong, air, deals!, Swipe Up, BES...
# 4                                                153

# %%
def restructure(df1):
    cols = [[], [], [], [], [], []]
    for i in range(len(df1)):
        lis = df1.iloc[i,0].split("&")
        for k in range(6):
            try:
                cols[k].append(lis[k])
            except:
                cols[k].append("NAv")
    df_new = pd.DataFrame()

    df_new["game_key"] = cols[0]
    df_new[f"request_id"] = cols[1]
    df_new[f"feature"] = cols[2]
    df_new[f"feature_type"] = cols[3]
    df_new[f"feature_variety"] = cols[4]
    df_new[f"sub_feature"] = cols[5]
    df_new[f"feature_value"] = df1.iloc[:,1].tolist()
    return df_new

# %%
restructure(df2).head(15)
# Out:
#                                 col0                  col1    col2  \
# 0   f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  labels
# 1   f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  labels
# 2   f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67    text
# 3   f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67    text
# 4   f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
# 5   f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
# 6   f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
# 7   f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
# 8   f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
# 9   f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
# 10  f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
# 11  f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
# 12  f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
# 13  f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
# 14  f910338e60315f02812b05e932068f47  1028d033d74dd2e24f67  colors
#
#              col3 col4        col5  \
# 0      engagement  NAv         NAv
# 1   click_through  NAv         NAv
# 2      engagement  NAv         NAv
# 3   click_through  NAv         NAv
# 4      engagement    1         red
# 5      engagement    1       green
# 6      engagement    1        blue
# 7      engagement    1  proportion
# 8      engagement    1  saturation
# 9      engagement    1  luminosity
# 10     engagement    2         red
# 11     engagement    2       green
# 12     engagement    2        blue
# 13     engagement    2  proportion
# 14     engagement    2  saturation
#
#                                                  col6
# 0                     [Asphalt, Tarmac, Road, Runway]
# 1                     [Asphalt, Tarmac, Road, Runway]
# 2   [Amazing Hong Kong, air, deals!, Swipe Up, BES...
# 3   [Amazing Hong Kong, air, deals!, Swipe Up, BES...
# 4                                                 153
# 5                                                 154
# 6                                                 167
# 7                                            0.219551
# 8                                            0.073684
# 9                                            0.627451
# 10                                                 32
# 11                                                 43
# 12                                                 66
# 13                                           0.148237
# 14                                           0.346939
