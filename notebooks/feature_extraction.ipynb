# %% [markdown]
# # Extracting features from images

# %%
# importing libraries

import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from skimage.io import imread, imshow
from skimage.filters import prewitt_h,prewitt_v

# %%
# importing script
sys.path.append(os.path.abspath("../scripts/python"))

from feature_extractor import extractor

# %%
# Test loading
image = imread('../data/Creative Assets_/080ac9223009886832e1a5e426a55910-f4c02eb05e03c3c6c9fd.png', as_gray=True)
imshow(image)

# %%
extractor(5)
# Out:
# successfully extracted
# Completed
#                                             game_key           shape  \
# 0  080ac9223009886832e1a5e426a55910-f4c02eb05e03c...  (832, 1295, 4)
# 1  e94d0020bf0875e4d0883d8d1ec8f963-b6d390c93ad74...  (832, 1295, 4)
# 2  915c850bc7b4ead0fef54f2b3c325051-365082ca9a2e1...  (832, 1295, 4)
# 3  9401d1ff9026dd736d16ca0ddac073ea-bb9541a313fc8...  (832, 1295, 4)
# 4  ecc6562c52ea0a03f794e7cec023bd0b-54e2394a53a3b...  (832, 1295, 4)
#
#                                       feature_matrix
# 0  [[159.25 184.   206.25 ... 606.   606.   606. ...
# 1  [[487.75 487.75 487.75 ... 606.   606.   606. ...
# 2  [[514.25 518.25 518.25 ... 606.   606.   606. ...
# 3  [[534.75 534.75 534.75 ... 606.   606.   606. ...
# 4  [[596.5  596.5  600.75 ... 606.   606.   606. ...
